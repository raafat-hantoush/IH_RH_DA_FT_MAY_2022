# %% [markdown]
#  ### Sending requests

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = response = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# Check [here](https://www.restapitutorial.com/httpstatuscodes.html) the meaning of each error code.

# %% [markdown]
# ### json response

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")
print(response.status_code)
results = response.json()
results[0]["title"]
# Out:
# 200
# 'delectus aut autem'

# %%
import pandas as pd
# json to pandas dataframe
pd.DataFrame(results)
# Out:
#      userId   id                                              title  completed
# 0         1    1                                 delectus aut autem      False
# 1         1    2                 quis ut nam facilis et officia qui      False
# 2         1    3                                fugiat veniam minus      False
# 3         1    4                                   et porro tempora       True
# 4         1    5  laboriosam mollitia et enim quasi adipisci qui...      False
# ..      ...  ...                                                ...        ...
# 195      10  196                consequuntur aut ut fugit similique       True
# 196      10  197                  dignissimos quo nobis earum saepe       True
# 197      10  198                       quis eius est sint explicabo       True
# 198      10  199                       numquam repellendus a magnam       True
# 199      10  200                       ipsam aperiam voluptates qui      False
#
# [200 rows x 4 columns]

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
response = requests.get('https://api.github.com/events')

# %%
response.json()
# Out:
# [{'id': '21475092000',
#   'type': 'PushEvent',
#   'actor': {'id': 38650337,
#    'login': 'Jambo2018',
#    'display_login': 'Jambo2018',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jambo2018',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38650337?'},
#   'repo': {'id': 469427410,
#    'name': 'Jambo2018/react-polygon-cropper',
#    'url': 'https://api.github.com/repos/Jambo2018/react-polygon-cropper'},
#   'payload': {'push_id': 9723000668,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '0880a8bb17a589495ff995ab052e4ce364a5ed18',
#    'before': 'eef5261d3620acef03fdb7cc14553f53d84e2cec',
#    'commits': [{'sha': '0880a8bb17a589495ff995ab052e4ce364a5ed18',
#      'author': {'email': 'bxtx1992@gmail.com', 'name': 'bxtx1992@gmail.com'},
#      'message': 'fix package.json',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Jambo2018/react-polygon-cropper/commits/0880a8bb17a589495ff995ab052e4ce364a5ed18'}]},
#   'public': True,
#   'created_at': '2022-04-26T13:03:15Z'},
#  {'id': '21475090914',
#   'type': 'PushEvent',
#   'actor': {'id': 101595139,
#    'login': 'Gransotto2002',
#    'display_login': 'Gransotto2002',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Gransotto2002',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101595139?'},
#   'repo': {'id': 483427274,
#    'name': 'Gransotto2002/QR-Code-Generator',
#    'url': 'https://api.github.com/repos/Gransotto2002/QR-Code-Generator'},
#   'payload': {'push_id': 9723000111,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '78e880902505e3dd383edae7395288fcb6e9a6bb',
#    'before': '0d8206a9c965e83cded6b32dcb5bc70ec6a5f8cb',
#    'commits': [{'sha': '78e880902505e3dd383edae7395288fcb6e9a6bb',
#      'author': {'email': '101595139+Gransotto2002@users.noreply.github.com',
#       'name': 'Vitor Gabriel Gransotto'},
#      'message': 'Create README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Gransotto2002/QR-Code-Generator/commits/78e880902505e3dd383edae7395288fcb6e9a6bb'}]},
#   'public': True,
#   'created_at': '2022-04-26T13:03:12Z'},
#  {'id': '21475091289',
#   'type': 'PushEvent',
#   'actor': {'id': 76687631,
#    'login': 'krithika117',
#    'display_login': 'krithika117',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/krithika117',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/76687631?'},
#   'repo': {'id': 452227954,
#    'name': 'krithika117/beingkrithika',
#    'url': 'https://api.github.com/repos/krithika117/beingkrithika'},
#   'payload': {'push_id': 9723000262,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ff0525783bcb29e0bdb40f55e5de91f3a111761e',
#    'before': '08da440dcf27fef217d5507f3d1b33ff0ef058a4',
#    'commits': [{'sha': 'ff0525783bcb29e0bdb40f55e5de91f3a111761e',
#      'author': {'email': '76687631+krithika117@users.noreply.github.com',
#       'name': 'Krithika N'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/krithika117/beingkrithika/commits/ff0525783bcb29e0bdb40f55e5de91f3a111761e'}]},
#   'public': True,
#   'created_at': '2022-04-26T13:03:13Z'},
#  {'id': '21475092014',
#   'type': 'PushEvent',
#   'actor': {'id': 8057368,
#    'login': 'monzta',
#    'display_login': 'monzta',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/monzta',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8057368?'},
#   'repo': {'id': 58876201,
#    'name': 'easylist/easylist',
#    'url': 'https://api.github.com/repos/easylist/easylist'},
#   'payload': {'push_id': 9723000647,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': 'de654f5adea13f2a36969b9928106097d42ae349',
#    'before': '64818b0c94e9c8f1f11be6a207ce2c621a5de211',
#    'commits': [{'sha': 'de654f5adea13f2a36969b9928106097d42ae349',
#      'author': {'email': 'travis@travis-ci.org', 'name': 'TravisCI'},
#      'message': 'Publishing revision 16c7b6c',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/easylist/easylist/commits/de654f5adea13f2a36969b9928106097d42ae349'}]},
#   'public': True,
#   'created_at': '2022-04-26T13:03:15Z',
#   'org': {'id': 15652042,
#    'login': 'easylist',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/easylist',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15652042?'}},
#  {'id': '21475091288',
#   'type': 'PushEvent',
#   'actor': {'id': 89585989,
#    'login': 'Smrutthi',
#    'display_login': 'Smrutthi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Smrutthi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/89585989?'},
#   'repo': {'id': 485783953,
#    'name': 'Smrutthi/M2_Project',
#    'url': 'https://api.github.com/repos/Smrutthi/M2_Project'},
#   'payload': {'push_id': 9723000298,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'c0776026271f5e93d16710cf5715101f12a26e72',
#    'before': 'e5708be63778384186b31dc397b36dd58b3b93e3',
#    'commits': [{'sha': 'c0776026271f5e93d16710cf5715101f12a26e72',
#      'author': {'email': '89585989+Smrutthi@users.noreply.github.com',
#       'name': 'Smrutthi'},
#      'message': 'Create README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Smrutthi/M2_Project/commits/c0776026271f5e93d16710cf5715101f12a26e72'}]},
#   'public': True,
#   'created_at': '2022-04-26T13:03:13Z'},
#  {'id': '21475091635',
#   'type': 'PushEvent',
#   'actor': {'id': 8084401,
#    'login': 'famturiop',
#    'display_login': 'famturiop',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/famturiop',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8084401?'},
#   'repo': {'id': 470196260,
#    'name': 'famturiop/MeetingDateProposer',
#    'url': 'https://api.github.com/repos/famturiop/MeetingDateProposer'},
#   'payload': {'push_id': 9723000476,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/develop',
#    'head': '3c75f0fa90648f70bb806121cea69ad2c609664f',
#    'before': '319e4b0828b7302c1eba0187cedcf9377ee74488',
#    'commits': [{'sha': '3c75f0fa90648f70bb806121cea69ad2c609664f',
#      'author': {'email': 'vorobyev.seva.rules@gmail.com', 'name': 'famturiop'},
#      'message': 'Auth code request uri is now fetched from api\n\n* Connected-user-card component now sends an api request for auth code request uri instead of using open-new-window.service to build uri\n* Added BASE_URL injection token',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/famturiop/MeetingDateProposer/commits/3c75f0fa90648f70bb806121cea69ad2c609664f'}]},
#   'public': True,
#   'created_at': '2022-04-26T13:03:14Z'},
#  {'id': '21475091981',
#   'type': 'WatchEvent',
#   'actor': {'id': 18066733,
#    'login': 'chingdae1',
#    'display_login': 'chingdae1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chingdae1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18066733?'},
#   'repo': {'id': 219296564,
#    'name': 'msaltnet/smtm',
#    'url': 'https://api.github.com/repos/msaltnet/smtm'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2022-04-26T13:03:15Z'},
#  {'id': '21475091965',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 45442278,
#    'login': 'tvardero',
#    'display_login': 'tvardero',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tvardero',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45442278?'},
#   'repo': {'id': 484046472,
#    'name': 'tvardero/taChat.App',
#    'url': 'https://api.github.com/repos/tvardero/taChat.App'},
#   'payload': {'action': 'opened',
#    'number': 8,
#    'pull_request': {'url': 'https://api.github.com/repos/tvardero/taChat.App/pulls/8',
#     'id': 919395081,
#     'node_id': 'PR_kwDOHNn2iM42zNsJ',
#     'html_url': 'https://github.com/tvardero/taChat.App/pull/8',
#     'diff_url': 'https://github.com/tvardero/taChat.App/pull/8.diff',
#     'patch_url': 'https://github.com/tvardero/taChat.App/pull/8.patch',
#     'issue_url': 'https://api.github.com/repos/tvardero/taChat.App/issues/8',
#     'number': 8,
#     'state': 'open',
#     'locked': False,
#     'title': 'Monolith merge',
#     'user': {'login': 'tvardero',
#      'id': 45442278,
#      'node_id': 'MDQ6VXNlcjQ1NDQyMjc4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/45442278?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/tvardero',
#      'html_url': 'https://github.com/tvardero',
#      'followers_url': 'https://api.github.com/users/tvardero/followers',
#      'following_url': 'https://api.github.com/users/tvardero/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/tvardero/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/tvardero/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/tvardero/subscriptions',
#      'organizations_url': 'https://api.github.com/users/tvardero/orgs',
#      'repos_url': 'https://api.github.com/users/tvardero/repos',
#      'events_url': 'https://api.github.com/users/tvardero/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/tvardero/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': "Add RoomUser many-to-many relationship using specific entity\r\nAdd Perks\r\nAdd manage room page\r\nAdd add-user and leave-room functionality\r\nAd many more i dont remember...\r\n\r\nPartially closes #5 \r\nThere's still a lot TODOs and WIPs\r\n\r\nPartially closes #6 -> Add empty controller actions for deleting and editing messages",
#     'created_at': '2022-04-26T13:03:15Z',
#     'updated_at': '2022-04-26T13:03:15Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/tvardero/taChat.App/pulls/8/commits',
#     'review_comments_url': 'https://api.github.com/repos/tvardero/taChat.App/pulls/8/comments',
#     'review_comment_url': 'https://api.github.com/repos/tvardero/taChat.App/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/tvardero/taChat.App/issues/8/comments',
#     'statuses_url': 'https://api.github.com/repos/tvardero/taChat.App/statuses/ead4c4d58a3a1ba86ff1a7104f52e7d4bedf2cf6',
#     'head': {'label': 'tvardero:room-roles',
#      'ref': 'room-roles',
#      'sha': 'ead4c4d58a3a1ba86ff1a7104f52e7d4bedf2cf6',
#      'user': {'login': 'tvardero',
#       'id': 45442278,
#       'node_id': 'MDQ6VXNlcjQ1NDQyMjc4',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/45442278?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/tvardero',
#       'html_url': 'https://github.com/tvardero',
#       'followers_url': 'https://api.github.com/users/tvardero/followers',
#       'following_url': 'https://api.github.com/users/tvardero/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/tvardero/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/tvardero/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/tvardero/subscriptions',
#       'organizations_url': 'https://api.github.com/users/tvardero/orgs',
#       'repos_url': 'https://api.github.com/users/tvardero/repos',
#       'events_url': 'https://api.github.com/users/tvardero/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/tvardero/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 484046472,
#       'node_id': 'R_kgDOHNn2iA',
#       'name': 'taChat.App',
#       'full_name': 'tvardero/taChat.App',
#       'private': False,
#       'owner': {'login': 'tvardero',
#        'id': 45442278,
#        'node_id': 'MDQ6VXNlcjQ1NDQyMjc4',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/45442278?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/tvardero',
#        'html_url': 'https://github.com/tvardero',
#        'followers_url': 'https://api.github.com/users/tvardero/followers',
#        'following_url': 'https://api.github.com/users/tvardero/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/tvardero/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/tvardero/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/tvardero/subscriptions',
#        'organizations_url': 'https://api.github.com/users/tvardero/orgs',
#        'repos_url': 'https://api.github.com/users/tvardero/repos',
#        'events_url': 'https://api.github.com/users/tvardero/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/tvardero/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/tvardero/taChat.App',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/tvardero/taChat.App',
#       'forks_url': 'https://api.github.com/repos/tvardero/taChat.App/forks',
#       'keys_url': 'https://api.github.com/repos/tvardero/taChat.App/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/tvardero/taChat.App/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/tvardero/taChat.App/teams',
#       'hooks_url': 'https://api.github.com/repos/tvardero/taChat.App/hooks',
#       'issue_events_url': 'https://api.github.com/repos/tvardero/taChat.App/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/tvardero/taChat.App/events',
#       'assignees_url': 'https://api.github.com/repos/tvardero/taChat.App/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/tvardero/taChat.App/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/tvardero/taChat.App/tags',
#       'blobs_url': 'https://api.github.com/repos/tvardero/taChat.App/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/tvardero/taChat.App/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/tvardero/taChat.App/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/tvardero/taChat.App/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/tvardero/taChat.App/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/tvardero/taChat.App/languages',
#       'stargazers_url': 'https://api.github.com/repos/tvardero/taChat.App/stargazers',
#       'contributors_url': 'https://api.github.com/repos/tvardero/taChat.App/contributors',
#       'subscribers_url': 'https://api.github.com/repos/tvardero/taChat.App/subscribers',
#       'subscription_url': 'https://api.github.com/repos/tvardero/taChat.App/subscription',
#       'commits_url': 'https://api.github.com/repos/tvardero/taChat.App/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/tvardero/taChat.App/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/tvardero/taChat.App/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/tvardero/taChat.App/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/tvardero/taChat.App/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/tvardero/taChat.App/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/tvardero/taChat.App/merges',
#       'archive_url': 'https://api.github.com/repos/tvardero/taChat.App/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/tvardero/taChat.App/downloads',
#       'issues_url': 'https://api.github.com/repos/tvardero/taChat.App/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/tvardero/taChat.App/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/tvardero/taChat.App/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/tvardero/taChat.App/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/tvardero/taChat.App/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/tvardero/taChat.App/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/tvardero/taChat.App/deployments',
#       'created_at': '2022-04-21T12:40:17Z',
#       'updated_at': '2022-04-25T17:43:05Z',
#       'pushed_at': '2022-04-26T13:03:15Z',
#       'git_url': 'git://github.com/tvardero/taChat.App.git',
#       'ssh_url': 'git@github.com:tvardero/taChat.App.git',
#       'clone_url': 'https://github.com/tvardero/taChat.App.git',
#       'svn_url': 'https://github.com/tvardero/taChat.App',
#       'homepage': None,
#       'size': 24,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'C#',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 5,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 5,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'tvardero:main',
#      'ref': 'main',
#      'sha': 'deb2065aa56365dbf4b50a2a4ac574250b2899bf',
#      'user': {'login': 'tvardero',
#       'id': 45442278,
#       'node_id': 'MDQ6VXNlcjQ1NDQyMjc4',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/45442278?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/tvardero',
#       'html_url': 'https://github.com/tvardero',
#       'followers_url': 'https://api.github.com/users/tvardero/followers',
#       'following_url': 'https://api.github.com/users/tvardero/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/tvardero/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/tvardero/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/tvardero/subscriptions',
#       'organizations_url': 'https://api.github.com/users/tvardero/orgs',
#       'repos_url': 'https://api.github.com/users/tvardero/repos',
#       'events_url': 'https://api.github.com/users/tvardero/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/tvardero/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 484046472,
#       'node_id': 'R_kgDOHNn2iA',
#       'name': 'taChat.App',
#       'full_name': 'tvardero/taChat.App',
#       'private': False,
#       'owner': {'login': 'tvardero',
#        'id': 45442278,
#        'node_id': 'MDQ6VXNlcjQ1NDQyMjc4',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/45442278?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/tvardero',
#        'html_url': 'https://github.com/tvardero',
#        'followers_url': 'https://api.github.com/users/tvardero/followers',
#        'following_url': 'https://api.github.com/users/tvardero/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/tvardero/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/tvardero/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/tvardero/subscriptions',
#        'organizations_url': 'https://api.github.com/users/tvardero/orgs',
#        'repos_url': 'https://api.github.com/users/tvardero/repos',
#        'events_url': 'https://api.github.com/users/tvardero/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/tvardero/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/tvardero/taChat.App',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/tvardero/taChat.App',
#       'forks_url': 'https://api.github.com/repos/tvardero/taChat.App/forks',
#       'keys_url': 'https://api.github.com/repos/tvardero/taChat.App/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/tvardero/taChat.App/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/tvardero/taChat.App/teams',
#       'hooks_url': 'https://api.github.com/repos/tvardero/taChat.App/hooks',
#       'issue_events_url': 'https://api.github.com/repos/tvardero/taChat.App/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/tvardero/taChat.App/events',
#       'assignees_url': 'https://api.github.com/repos/tvardero/taChat.App/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/tvardero/taChat.App/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/tvardero/taChat.App/tags',
#       'blobs_url': 'https://api.github.com/repos/tvardero/taChat.App/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/tvardero/taChat.App/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/tvardero/taChat.App/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/tvardero/taChat.App/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/tvardero/taChat.App/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/tvardero/taChat.App/languages',
#       'stargazers_url': 'https://api.github.com/repos/tvardero/taChat.App/stargazers',
#       'contributors_url': 'https://api.github.com/repos/tvardero/taChat.App/contributors',
#       'subscribers_url': 'https://api.github.com/repos/tvardero/taChat.App/subscribers',
#       'subscription_url': 'https://api.github.com/repos/tvardero/taChat.App/subscription',
#       'commits_url': 'https://api.github.com/repos/tvardero/taChat.App/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/tvardero/taChat.App/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/tvardero/taChat.App/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/tvardero/taChat.App/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/tvardero/taChat.App/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/tvardero/taChat.App/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/tvardero/taChat.App/merges',
#       'archive_url': 'https://api.github.com/repos/tvardero/taChat.App/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/tvardero/taChat.App/downloads',
#       'issues_url': 'https://api.github.com/repos/tvardero/taChat.App/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/tvardero/taChat.App/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/tvardero/taChat.App/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/tvardero/taChat.App/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/tvardero/taChat.App/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/tvardero/taChat.App/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/tvardero/taChat.App/deployments',
#       'created_at': '2022-04-21T12:40:17Z',
#       'updated_at': '2022-04-25T17:43:05Z',
#       'pushed_at': '2022-04-26T13:03:15Z',
#       'git_url': 'git://github.com/tvardero/taChat.App.git',
#       'ssh_url': 'git@github.com:tvardero/taChat.App.git',
#       'clone_url': 'https://github.com/tvardero/taChat.App.git',
#       'svn_url': 'https://github.com/tvardero/taChat.App',
#       'homepage': None,
#       'size': 24,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'C#',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 5,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 5,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/tvardero/taChat.App/pulls/8'},
#      'html': {'href': 'https://github.com/tvardero/taChat.App/pull/8'},
#      'issue': {'href': 'https://api.github.com/repos/tvardero/taChat.App/issues/8'},
#      'comments': {'href': 'https://api.github.com/repos/tvardero/taChat.App/issues/8/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/tvardero/taChat.App/pulls/8/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/tvardero/taChat.App/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/tvardero/taChat.App/pulls/8/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/tvardero/taChat.App/statuses/ead4c4d58a3a1ba86ff1a7104f52e7d4bedf2cf6'}},
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 711,
#     'deletions': 117,
#     'changed_files': 15}},
#   'public': True,
#   'created_at': '2022-04-26T13:03:15Z'},
#  {'id': '21475091652',
#   'type': 'PushEvent',
#   'actor': {'id': 104293240,
#    'login': 'ICTBg',
#    'display_login': 'ICTBg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ICTBg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/104293240?'},
#   'repo': {'id': 484944745,
#    'name': 'ICTBg/READ-ME',
#    'url': 'https://api.github.com/repos/ICTBg/READ-ME'},
#   'payload': {'push_id': 9723000474,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd2c894a9756e114ca3418bf3464a86eec8ff7a8c',
#    'before': '6b86f6969693e957c5b22a815e060aefd76a1d0b',
#    'commits': [{'sha': 'd2c894a9756e114ca3418bf3464a86eec8ff7a8c',
#      'author': {'email': '104293240+ICTBg@users.noreply.github.com',
#       'name': 'ICTB GROUP NO.2'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ICTBg/READ-ME/commits/d2c894a9756e114ca3418bf3464a86eec8ff7a8c'}]},
#   'public': True,
#   'created_at': '2022-04-26T13:03:14Z'},
#  {'id': '21475092332',
#   'type': 'PushEvent',
#   'actor': {'id': 102516149,
#    'login': 'shsto',
#    'display_login': 'shsto',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shsto',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/102516149?'},
#   'repo': {'id': 480336626,
#    'name': 'shsto/crypt',
#    'url': 'https://api.github.com/repos/shsto/crypt'},
#   'payload': {'push_id': 9723000820,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'db52c52c907df9abe457fb16fa7003d7db2fa195',
#    'before': '0a9ba918066b28c4840ff015065a345cfd03395d',
#    'commits': [{'sha': 'db52c52c907df9abe457fb16fa7003d7db2fa195',
#      'author': {'email': '102516149+shsto@users.noreply.github.com',
#       'name': 'shsto'},
#      'message': 'Delete main directory',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shsto/crypt/commits/db52c52c907df9abe457fb16fa7003d7db2fa195'}]},
#   'public': True,
#   'created_at': '2022-04-26T13:03:16Z'},
#  {'id': '21475091638',
#   'type': 'IssuesEvent',
#   'actor': {'id': 86326137,
#    'login': 'bot-monkey-7',
#    'display_login': 'bot-monkey-7',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bot-monkey-7',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/86326137?'},
#   'repo': {'id': 379396407,
#    'name': 'test-organization-kkjeer/app-test-2',
#    'url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/issues/96432',
#     'repository_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2',
#     'labels_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/issues/96432/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/issues/96432/comments',
#     'events_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/issues/96432/events',
#     'html_url': 'https://github.com/test-organization-kkjeer/app-test-2/issues/96432',
#     'id': 1215926528,
#     'node_id': 'I_kwDOFp0hN85IeZEA',
#     'number': 96432,
#     'title': 'Auto monkey issue 2odkia',
#     'user': {'login': 'bot-monkey-7',
#      'id': 86326137,
#      'node_id': 'MDQ6VXNlcjg2MzI2MTM3',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/86326137?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/bot-monkey-7',
#      'html_url': 'https://github.com/bot-monkey-7',
#      'followers_url': 'https://api.github.com/users/bot-monkey-7/followers',
#      'following_url': 'https://api.github.com/users/bot-monkey-7/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/bot-monkey-7/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/bot-monkey-7/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/bot-monkey-7/subscriptions',
#      'organizations_url': 'https://api.github.com/users/bot-monkey-7/orgs',
#      'repos_url': 'https://api.github.com/users/bot-monkey-7/repos',
#      'events_url': 'https://api.github.com/users/bot-monkey-7/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/bot-monkey-7/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 3108857423,
#       'node_id': 'MDU6TGFiZWwzMTA4ODU3NDIz',
#       'url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/labels/Needs:%20Triage%20:mag:',
#       'name': 'Needs: Triage :mag:',
#       'color': 'ededed',
#       'default': False,
#       'description': ''},
#      {'id': 3108857514,
#       'node_id': 'MDU6TGFiZWwzMTA4ODU3NTE0',
#       'url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/labels/in%20pr',
#       'name': 'in pr',
#       'color': 'ededed',
#       'default': False,
#       'description': None}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2022-04-26T13:02:31Z',
#     'updated_at': '2022-04-26T13:03:14Z',
#     'closed_at': '2022-04-26T13:03:14Z',
#     'author_association': 'COLLABORATOR',
#     'active_lock_reason': None,
#     'body': '(2/2) Issue: "in-pr" and "fixed" labeling during PR lifetime\nvia `inPrLabeling/singlePr.test.ts`',
#     'reactions': {'url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/issues/96432/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/test-organization-kkjeer/app-test-2/issues/96432/timeline',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2022-04-26T13:03:14Z',
#   'org': {'id': 47997193,
#    'login': 'test-organization-kkjeer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/test-organization-kkjeer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47997193?'}},
#  {'id': '21475092287',
#   'type': 'PushEvent',
#   'actor': {'id': 15671329,
#    'login': '9dcw',
#    'display_login': '9dcw',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/9dcw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15671329?'},
#   'repo': {'id': 485485397,
#    'name': '9dcw/associationmarketing',
#    'url': 'https://api.github.com/repos/9dcw/associationmarketing'},
#   'payload': {'push_id': 9723000808,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '21629129b3860a512d2f883bb5f7a0f87fb79cf7',
#    'before': 'fbb7b2ed964b795a50479a641cfb05606e79096f',
#    'commits': [{'sha': '21629129b3860a512d2f883bb5f7a0f87fb79cf7',
#      'author': {'email': 'davecwright@gmail.com', 'name': '9dcw'},
#      'message': 'better menu',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/9dcw/associationmarketing/commits/21629129b3860a512d2f883bb5f7a0f87fb79cf7'}]},
#   'public': True,
#   'created_at': '2022-04-26T13:03:16Z'},
#  {'id': '21475092660',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 240284175,
#    'name': 'nationalarchives/tdr-generated-graphql',
#    'url': 'https://api.github.com/repos/nationalarchives/tdr-generated-graphql'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/ts/graphql-16.4.0',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-04-26T13:03:17Z',
#   'org': {'id': 10154228,
#    'login': 'nationalarchives',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/nationalarchives',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10154228?'}},
#  {'id': '21475091574',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 426008314,
#    'name': 'mpcamargo1/mpcamargo1',
#    'url': 'https://api.github.com/repos/mpcamargo1/mpcamargo1'},
#   'payload': {'push_id': 9723000426,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': 'bd6a1ae60e0eeb8c02a9fcead4e7e60e9ab559e5',
#    'before': 'abaa184af9fe09ba152bbf704e91400272191b5c',
#    'commits': [{'sha': 'bd6a1ae60e0eeb8c02a9fcead4e7e60e9ab559e5',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mpcamargo1/mpcamargo1/commits/bd6a1ae60e0eeb8c02a9fcead4e7e60e9ab559e5'}]},
#   'public': True,
#   'created_at': '2022-04-26T13:03:14Z'},
#  {'id': '21475092312',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 18140164,
#    'login': 'loaddss',
#    'display_login': 'loaddss',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/loaddss',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18140164?'},
#   'repo': {'id': 430749584,
#    'name': 'OneKeyHQ/app-monorepo',
#    'url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo'},
#   'payload': {'action': 'closed',
#    'number': 600,
#    'pull_request': {'url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/pulls/600',
#     'id': 917587927,
#     'node_id': 'PR_kwDOGay3kM42sUfX',
#     'html_url': 'https://github.com/OneKeyHQ/app-monorepo/pull/600',
#     'diff_url': 'https://github.com/OneKeyHQ/app-monorepo/pull/600.diff',
#     'patch_url': 'https://github.com/OneKeyHQ/app-monorepo/pull/600.patch',
#     'issue_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/issues/600',
#     'number': 600,
#     'state': 'closed',
#     'locked': False,
#     'title': 'fix: add local connect link and basic device connection at web',
#     'user': {'login': 'loaddss',
#      'id': 18140164,
#      'node_id': 'MDQ6VXNlcjE4MTQwMTY0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/18140164?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/loaddss',
#      'html_url': 'https://github.com/loaddss',
#      'followers_url': 'https://api.github.com/users/loaddss/followers',
#      'following_url': 'https://api.github.com/users/loaddss/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/loaddss/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/loaddss/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/loaddss/subscriptions',
#      'organizations_url': 'https://api.github.com/users/loaddss/orgs',
#      'repos_url': 'https://api.github.com/users/loaddss/repos',
#      'events_url': 'https://api.github.com/users/loaddss/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/loaddss/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2022-04-25T01:37:17Z',
#     'updated_at': '2022-04-26T13:03:16Z',
#     'closed_at': '2022-04-26T13:03:16Z',
#     'merged_at': None,
#     'merge_commit_sha': 'bba2854def739c35a6f2019a33d823f3afcf9e18',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': True,
#     'commits_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/pulls/600/commits',
#     'review_comments_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/pulls/600/comments',
#     'review_comment_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/issues/600/comments',
#     'statuses_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/statuses/17e0a99e778bcd24fe713fb27274e4d9e890d607',
#     'head': {'label': 'OneKeyHQ:fix/device',
#      'ref': 'fix/device',
#      'sha': '17e0a99e778bcd24fe713fb27274e4d9e890d607',
#      'user': {'login': 'OneKeyHQ',
#       'id': 61685601,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYxNjg1NjAx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/61685601?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/OneKeyHQ',
#       'html_url': 'https://github.com/OneKeyHQ',
#       'followers_url': 'https://api.github.com/users/OneKeyHQ/followers',
#       'following_url': 'https://api.github.com/users/OneKeyHQ/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/OneKeyHQ/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/OneKeyHQ/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/OneKeyHQ/subscriptions',
#       'organizations_url': 'https://api.github.com/users/OneKeyHQ/orgs',
#       'repos_url': 'https://api.github.com/users/OneKeyHQ/repos',
#       'events_url': 'https://api.github.com/users/OneKeyHQ/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/OneKeyHQ/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 430749584,
#       'node_id': 'R_kgDOGay3kA',
#       'name': 'app-monorepo',
#       'full_name': 'OneKeyHQ/app-monorepo',
#       'private': False,
#       'owner': {'login': 'OneKeyHQ',
#        'id': 61685601,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYxNjg1NjAx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/61685601?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/OneKeyHQ',
#        'html_url': 'https://github.com/OneKeyHQ',
#        'followers_url': 'https://api.github.com/users/OneKeyHQ/followers',
#        'following_url': 'https://api.github.com/users/OneKeyHQ/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/OneKeyHQ/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/OneKeyHQ/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/OneKeyHQ/subscriptions',
#        'organizations_url': 'https://api.github.com/users/OneKeyHQ/orgs',
#        'repos_url': 'https://api.github.com/users/OneKeyHQ/repos',
#        'events_url': 'https://api.github.com/users/OneKeyHQ/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/OneKeyHQ/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/OneKeyHQ/app-monorepo',
#       'description': "👛 The world's first truly open source crypto wallet runs on all platforms: iOS, Android, Windows, macOS, Linux, Oculus Quest, Chrome, Firefox... and more. Follow up to get updated, we need your star  ⭐️ .",
#       'fork': False,
#       'url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo',
#       'forks_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/forks',
#       'keys_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/teams',
#       'hooks_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/hooks',
#       'issue_events_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/events',
#       'assignees_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/tags',
#       'blobs_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/languages',
#       'stargazers_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/stargazers',
#       'contributors_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/contributors',
#       'subscribers_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/subscribers',
#       'subscription_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/subscription',
#       'commits_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/merges',
#       'archive_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/downloads',
#       'issues_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/deployments',
#       'created_at': '2021-11-22T14:54:51Z',
#       'updated_at': '2022-04-24T23:19:55Z',
#       'pushed_at': '2022-04-26T13:02:33Z',
#       'git_url': 'git://github.com/OneKeyHQ/app-monorepo.git',
#       'ssh_url': 'git@github.com:OneKeyHQ/app-monorepo.git',
#       'clone_url': 'https://github.com/OneKeyHQ/app-monorepo.git',
#       'svn_url': 'https://github.com/OneKeyHQ/app-monorepo',
#       'homepage': 'https://app.test.onekey.so',
#       'size': 71896,
#       'stargazers_count': 61,
#       'watchers_count': 61,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 19,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 7,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': ['android',
#        'bitcoin',
#        'blockchain',
#        'crypto',
#        'defi',
#        'electron',
#        'ethereum',
#        'expo',
#        'ios',
#        'mobile',
#        'native',
#        'near',
#        'react',
#        'react-native',
#        'redux',
#        'solana',
#        'universal',
#        'wallet',
#        'web'],
#       'visibility': 'public',
#       'forks': 19,
#       'open_issues': 7,
#       'watchers': 61,
#       'default_branch': 'onekey'}},
#     'base': {'label': 'OneKeyHQ:onekey',
#      'ref': 'onekey',
#      'sha': 'fb6cb7cb42d0c9fb8e534495b2440fe01f662549',
#      'user': {'login': 'OneKeyHQ',
#       'id': 61685601,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYxNjg1NjAx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/61685601?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/OneKeyHQ',
#       'html_url': 'https://github.com/OneKeyHQ',
#       'followers_url': 'https://api.github.com/users/OneKeyHQ/followers',
#       'following_url': 'https://api.github.com/users/OneKeyHQ/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/OneKeyHQ/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/OneKeyHQ/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/OneKeyHQ/subscriptions',
#       'organizations_url': 'https://api.github.com/users/OneKeyHQ/orgs',
#       'repos_url': 'https://api.github.com/users/OneKeyHQ/repos',
#       'events_url': 'https://api.github.com/users/OneKeyHQ/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/OneKeyHQ/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 430749584,
#       'node_id': 'R_kgDOGay3kA',
#       'name': 'app-monorepo',
#       'full_name': 'OneKeyHQ/app-monorepo',
#       'private': False,
#       'owner': {'login': 'OneKeyHQ',
#        'id': 61685601,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYxNjg1NjAx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/61685601?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/OneKeyHQ',
#        'html_url': 'https://github.com/OneKeyHQ',
#        'followers_url': 'https://api.github.com/users/OneKeyHQ/followers',
#        'following_url': 'https://api.github.com/users/OneKeyHQ/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/OneKeyHQ/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/OneKeyHQ/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/OneKeyHQ/subscriptions',
#        'organizations_url': 'https://api.github.com/users/OneKeyHQ/orgs',
#        'repos_url': 'https://api.github.com/users/OneKeyHQ/repos',
#        'events_url': 'https://api.github.com/users/OneKeyHQ/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/OneKeyHQ/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/OneKeyHQ/app-monorepo',
#       'description': "👛 The world's first truly open source crypto wallet runs on all platforms: iOS, Android, Windows, macOS, Linux, Oculus Quest, Chrome, Firefox... and more. Follow up to get updated, we need your star  ⭐️ .",
#       'fork': False,
#       'url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo',
#       'forks_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/forks',
#       'keys_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/teams',
#       'hooks_url': 'https://api.github.com/repos/OneKeyHQ/app-monorepo/hooks',
# ...
#     {'sha': '39f410340246638c27433913a6a3feeab4e3352e',
#      'author': {'email': 'Tudor.pop@connatix.com', 'name': 'PopTudorSilviu'},
#      'message': 'modified controllers and added dependency injection',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/AndreiToader1/connatix-internship/commits/39f410340246638c27433913a6a3feeab4e3352e'},
#     {'sha': '9cae41a6ac7a7484618d1ad0bca8334aa5a79bf3',
#      'author': {'email': 'Tudor.pop@connatix.com', 'name': 'PopTudorSilviu'},
#      'message': 'Added bin, obj, .user, .idea, *.orig to .gitignore',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/AndreiToader1/connatix-internship/commits/9cae41a6ac7a7484618d1ad0bca8334aa5a79bf3'},
#     {'sha': '290e3415555e3011b4fb8f26323de9586b684a58',
#      'author': {'email': 'Tudor.pop@connatix.com', 'name': 'PopTudorSilviu'},
#      'message': 'Created a folder Services, changed the file name UserRepository to UserService and moved it in Services folder. Added a new file ApiConstants in a new folder, Utils, where I added a base url constant.',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/AndreiToader1/connatix-internship/commits/290e3415555e3011b4fb8f26323de9586b684a58'},
#     {'sha': 'c36563b28ed90da1e01d283839f4940c4e0d5f45',
#      'author': {'email': 'andrei.aciobanitei@connatix.com',
#       'name': 'aNdrei42O'},
#      'message': 'Updated the modify\n\n- Eliminated camel typing\n- Modified the return type to be Task<UserViewModel>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/AndreiToader1/connatix-internship/commits/c36563b28ed90da1e01d283839f4940c4e0d5f45'},
#     {'sha': '8cef4419bb5d18afa60fd46a0fde6a9237a25159',
#      'author': {'email': 'andrei.aciobanitei@connatix.com',
#       'name': 'aNdrei42O'},
#      'message': 'FIxed camel case',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/AndreiToader1/connatix-internship/commits/8cef4419bb5d18afa60fd46a0fde6a9237a25159'},
#     {'sha': 'e7c31126edef3858c68e1e865a0c4786b8892bda',
#      'author': {'email': 'andrei.aciobanitei@connatix.com',
#       'name': 'aNdrei42O'},
#      'message': "Merge branch 'INTERN-31' into INTERN-26",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/AndreiToader1/connatix-internship/commits/e7c31126edef3858c68e1e865a0c4786b8892bda'}]},
#   'public': True,
#   'created_at': '2022-04-26T13:03:16Z'},
#  {'id': '21475091940',
#   'type': 'PushEvent',
#   'actor': {'id': 2687598,
#    'login': 'milesholt',
#    'display_login': 'milesholt',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/milesholt',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2687598?'},
#   'repo': {'id': 247480564,
#    'name': 'milesholt/autotrade1',
#    'url': 'https://api.github.com/repos/milesholt/autotrade1'},
#   'payload': {'push_id': 9723000607,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/version2',
#    'head': 'c37dd21664b2706646d5e61e7096252362c94956',
#    'before': '9ef9a05b3b2c45ef78d6ded1a7bc372d7fb8f56c',
#    'commits': [{'sha': 'c37dd21664b2706646d5e61e7096252362c94956',
#      'author': {'email': 'contact@milesholt.co.uk', 'name': 'milesholt'},
#      'message': 'File updated - April 26, 2022 2:03 PM',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/milesholt/autotrade1/commits/c37dd21664b2706646d5e61e7096252362c94956'}]},
#   'public': True,
#   'created_at': '2022-04-26T13:03:15Z'},
#  {'id': '21475091915',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 40209326,
#    'login': 'netlify[bot]',
#    'display_login': 'netlify',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/netlify[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40209326?'},
#   'repo': {'id': 479319524,
#    'name': 'ChristopherNoelGoldsmith/weather_app',
#    'url': 'https://api.github.com/repos/ChristopherNoelGoldsmith/weather_app'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/ChristopherNoelGoldsmith/weather_app/issues/1',
#     'repository_url': 'https://api.github.com/repos/ChristopherNoelGoldsmith/weather_app',
#     'labels_url': 'https://api.github.com/repos/ChristopherNoelGoldsmith/weather_app/issues/1/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/ChristopherNoelGoldsmith/weather_app/issues/1/comments',
#     'events_url': 'https://api.github.com/repos/ChristopherNoelGoldsmith/weather_app/issues/1/events',
#     'html_url': 'https://github.com/ChristopherNoelGoldsmith/weather_app/pull/1',
#     'id': 1215925878,
#     'node_id': 'PR_kwDOHJHV5M42zNVs',
#     'number': 1,
#     'title': 'UI redesign',
#     'user': {'login': 'ChristopherNoelGoldsmith',
#      'id': 98594058,
#      'node_id': 'U_kgDOBeBtCg',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/98594058?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ChristopherNoelGoldsmith',
#      'html_url': 'https://github.com/ChristopherNoelGoldsmith',
#      'followers_url': 'https://api.github.com/users/ChristopherNoelGoldsmith/followers',
#      'following_url': 'https://api.github.com/users/ChristopherNoelGoldsmith/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ChristopherNoelGoldsmith/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ChristopherNoelGoldsmith/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ChristopherNoelGoldsmith/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ChristopherNoelGoldsmith/orgs',
#      'repos_url': 'https://api.github.com/users/ChristopherNoelGoldsmith/repos',
#      'events_url': 'https://api.github.com/users/ChristopherNoelGoldsmith/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ChristopherNoelGoldsmith/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2022-04-26T13:02:02Z',
#     'updated_at': '2022-04-26T13:03:15Z',
#     'closed_at': '2022-04-26T13:02:15Z',
#     'author_association': 'OWNER',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/ChristopherNoelGoldsmith/weather_app/pulls/1',
#      'html_url': 'https://github.com/ChristopherNoelGoldsmith/weather_app/pull/1',
#      'diff_url': 'https://github.com/ChristopherNoelGoldsmith/weather_app/pull/1.diff',
#      'patch_url': 'https://github.com/ChristopherNoelGoldsmith/weather_app/pull/1.patch',
#      'merged_at': '2022-04-26T13:02:15Z'},
#     'body': 'Site is functional and improved.',
#     'reactions': {'url': 'https://api.github.com/repos/ChristopherNoelGoldsmith/weather_app/issues/1/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/ChristopherNoelGoldsmith/weather_app/issues/1/timeline',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/ChristopherNoelGoldsmith/weather_app/issues/comments/1109770633',
#     'html_url': 'https://github.com/ChristopherNoelGoldsmith/weather_app/pull/1#issuecomment-1109770633',
#     'issue_url': 'https://api.github.com/repos/ChristopherNoelGoldsmith/weather_app/issues/1',
#     'id': 1109770633,
#     'node_id': 'IC_kwDOHJHV5M5CJcGJ',
#     'user': {'login': 'netlify[bot]',
#      'id': 40209326,
#      'node_id': 'MDM6Qm90NDAyMDkzMjY=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/13473?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/netlify%5Bbot%5D',
#      'html_url': 'https://github.com/apps/netlify',
#      'followers_url': 'https://api.github.com/users/netlify%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/netlify%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/netlify%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/netlify%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/netlify%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/netlify%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/netlify%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/netlify%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/netlify%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2022-04-26T13:03:15Z',
#     'updated_at': '2022-04-26T13:03:15Z',
#     'author_association': 'NONE',
#     'body': '### <span aria-hidden="true">👷</span> Deploy Preview for *golden-youtiao-47537f* processing.\n\n\n|  Name | Link |\n|---------------------------------|------------------------|\n|<span aria-hidden="true">🔨</span> Latest commit | 90d4710f77903e91aae248d0babe069f041a6e4a |\n|<span aria-hidden="true">🔍</span> Latest deploy log | https://app.netlify.com/sites/golden-youtiao-47537f/deploys/6267ed4b257a080009e4025f |',
#     'reactions': {'url': 'https://api.github.com/repos/ChristopherNoelGoldsmith/weather_app/issues/comments/1109770633/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2022-04-26T13:03:15Z'},
#  {'id': '21475091555',
#   'type': 'DeleteEvent',
#   'actor': {'id': 71354125,
#    'login': 'aws-connector-for-github[bot]',
#    'display_login': 'aws-connector-for-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aws-connector-for-github[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71354125?'},
#   'repo': {'id': 429551228,
#    'name': 'bullet-dev-team/python-pyramid-public',
#    'url': 'https://api.github.com/repos/bullet-dev-team/python-pyramid-public'},
#   'payload': {'ref': 'cicd-e2e-svgmgp',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-04-26T13:03:14Z'},
#  {'id': '21475091556',
#   'type': 'CreateEvent',
#   'actor': {'id': 82694104,
#    'login': 'FateJacobson',
#    'display_login': 'FateJacobson',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/FateJacobson',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/82694104?'},
#   'repo': {'id': 485788648,
#    'name': 'FateJacobson/Connect-Four',
#    'url': 'https://api.github.com/repos/FateJacobson/Connect-Four'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-04-26T13:03:14Z'},
#  {'id': '21475091507',
#   'type': 'PushEvent',
#   'actor': {'id': 92665023,
#    'login': 'patilsayali9822',
#    'display_login': 'patilsayali9822',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/patilsayali9822',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/92665023?'},
#   'repo': {'id': 483328876,
#    'name': 'patilsayali9822/corejava',
#    'url': 'https://api.github.com/repos/patilsayali9822/corejava'},
#   'payload': {'push_id': 9723000398,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '52963124aa80d178af1c2ebda810025a18461d1a',
#    'before': 'bb2947df51bfef3772fc578644f1b306be991139',
#    'commits': [{'sha': '52963124aa80d178af1c2ebda810025a18461d1a',
#      'author': {'email': '92665023+patilsayali9822@users.noreply.github.com',
#       'name': 'patilsayali9822'},
#      'message': 'First Commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/patilsayali9822/corejava/commits/52963124aa80d178af1c2ebda810025a18461d1a'}]},
#   'public': True,
#   'created_at': '2022-04-26T13:03:14Z'},
#  {'id': '21475091875',
#   'type': 'PushEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 135867643,
#    'name': 'poad/aws-example',
#    'url': 'https://api.github.com/repos/poad/aws-example'},
#   'payload': {'push_id': 9723000546,
#    'size': 3,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dependabot/npm_and_yarn/lambda/layer/layer/constructs-10.0.126',
#    'head': '475f68bfd25a2255c1cd11ee2b4fbf0b39c83b5d',
#    'before': '7dbdb4d66a0e0d5fb73614134da1329169305ba3',
#    'commits': [{'sha': '6f6a408f33ebfeff42a172a8701ba173c47ae0c1',
#      'author': {'email': '49699333+dependabot[bot]@users.noreply.github.com',
#       'name': 'dependabot[bot]'},
#      'message': 'Bump electron-to-chromium in /cognito/cognito-saml-next-js/infra\n\nBumps [electron-to-chromium](https://github.com/kilian/electron-to-chromium) from 1.4.120 to 1.4.121.\n- [Release notes](https://github.com/kilian/electron-to-chromium/releases)\n- [Changelog](https://github.com/Kilian/electron-to-chromium/blob/master/CHANGELOG.md)\n- [Commits](https://github.com/kilian/electron-to-chromium/compare/v1.4.120...v1.4.121)\n\n---\nupdated-dependencies:\n- dependency-name: electron-to-chromium\n  dependency-type: indirect\n  update-type: version-update:semver-patch\n...\n\nSigned-off-by: dependabot[bot] <support@github.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/poad/aws-example/commits/6f6a408f33ebfeff42a172a8701ba173c47ae0c1'},
#     {'sha': '71204fd9fba1e555a9c113b91e630fea5b51ed0e',
#      'author': {'email': '49699333+dependabot[bot]@users.noreply.github.com',
#       'name': 'dependabot[bot]'},
#      'message': 'Merge pull request #7721 from poad/dependabot/npm_and_yarn/cognito/cognito-saml-next-js/infra/electron-to-chromium-1.4.121',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/poad/aws-example/commits/71204fd9fba1e555a9c113b91e630fea5b51ed0e'},
#     {'sha': '475f68bfd25a2255c1cd11ee2b4fbf0b39c83b5d',
#      'author': {'email': '49699333+dependabot[bot]@users.noreply.github.com',
#       'name': 'dependabot[bot]'},
#      'message': 'Bump constructs from 10.0.125 to 10.0.126 in /lambda/layer/layer\n\nBumps [constructs](https://github.com/aws/constructs) from 10.0.125 to 10.0.126.\n- [Release notes](https://github.com/aws/constructs/releases)\n- [Commits](https://github.com/aws/constructs/compare/v10.0.125...v10.0.126)\n\n---\nupdated-dependencies:\n- dependency-name: constructs\n  dependency-type: direct:production\n  update-type: version-update:semver-patch\n...\n\nSigned-off-by: dependabot[bot] <support@github.com>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/poad/aws-example/commits/475f68bfd25a2255c1cd11ee2b4fbf0b39c83b5d'}]},
#   'public': True,
#   'created_at': '2022-04-26T13:03:15Z'},
#  {'id': '21475092222',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 437985702,
#    'name': 'franciscodantas/franciscodantas',
#    'url': 'https://api.github.com/repos/franciscodantas/franciscodantas'},
#   'payload': {'push_id': 9723000769,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '793622c0bcdc77a47909aae5bfd1687dbad04f65',
#    'before': '13ba4c7addb1ba3709c1a640ff2d511c2db7872f',
#    'commits': [{'sha': '793622c0bcdc77a47909aae5bfd1687dbad04f65',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/franciscodantas/franciscodantas/commits/793622c0bcdc77a47909aae5bfd1687dbad04f65'}]},
#   'public': True,
#   'created_at': '2022-04-26T13:03:16Z'}]

# %%
pd.DataFrame(response.json())
# Out:
#              id               type  \
# 0   21475092000          PushEvent
# 1   21475090914          PushEvent
# 2   21475091289          PushEvent
# 3   21475092014          PushEvent
# 4   21475091288          PushEvent
# 5   21475091635          PushEvent
# 6   21475091981         WatchEvent
# 7   21475091965   PullRequestEvent
# 8   21475091652          PushEvent
# 9   21475092332          PushEvent
# 10  21475091638        IssuesEvent
# 11  21475092287          PushEvent
# 12  21475092660        CreateEvent
# 13  21475091574          PushEvent
# 14  21475092312   PullRequestEvent
# 15  21475091596          PushEvent
# 16  21475092654   PullRequestEvent
# 17  21475092619          PushEvent
# 18  21475092309          PushEvent
# 19  21475091603          PushEvent
# 20  21475091938          PushEvent
# 21  21475091948          PushEvent
# 22  21475092271          PushEvent
# 23  21475091940          PushEvent
# 24  21475091915  IssueCommentEvent
# 25  21475091555        DeleteEvent
# 26  21475091556        CreateEvent
# 27  21475091507          PushEvent
# 28  21475091875          PushEvent
# 29  21475092222          PushEvent
#
#                                                 actor  \
# 0   {'id': 38650337, 'login': 'Jambo2018', 'displa...
# 1   {'id': 101595139, 'login': 'Gransotto2002', 'd...
# 2   {'id': 76687631, 'login': 'krithika117', 'disp...
# 3   {'id': 8057368, 'login': 'monzta', 'display_lo...
# 4   {'id': 89585989, 'login': 'Smrutthi', 'display...
# 5   {'id': 8084401, 'login': 'famturiop', 'display...
# 6   {'id': 18066733, 'login': 'chingdae1', 'displa...
# 7   {'id': 45442278, 'login': 'tvardero', 'display...
# 8   {'id': 104293240, 'login': 'ICTBg', 'display_l...
# 9   {'id': 102516149, 'login': 'shsto', 'display_l...
# 10  {'id': 86326137, 'login': 'bot-monkey-7', 'dis...
# 11  {'id': 15671329, 'login': '9dcw', 'display_log...
# 12  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 13  {'id': 41898282, 'login': 'github-actions[bot]...
# 14  {'id': 18140164, 'login': 'loaddss', 'display_...
# 15  {'id': 20303122, 'login': 'dvr16', 'display_lo...
# 16  {'id': 2614900, 'login': 'cyBerta', 'display_l...
# 17  {'id': 10129688, 'login': 'fanteos', 'display_...
# 18  {'id': 12523742, 'login': 'waittttting', 'disp...
# 19  {'id': 103194481, 'login': 'KazantsevaJane', '...
# 20  {'id': 9757926, 'login': 'fsultani', 'display_...
# 21  {'id': 41898282, 'login': 'github-actions[bot]...
# 22  {'id': 9108538, 'login': 'Annno', 'display_log...
# 23  {'id': 2687598, 'login': 'milesholt', 'display...
# 24  {'id': 40209326, 'login': 'netlify[bot]', 'dis...
# 25  {'id': 71354125, 'login': 'aws-connector-for-g...
# 26  {'id': 82694104, 'login': 'FateJacobson', 'dis...
# 27  {'id': 92665023, 'login': 'patilsayali9822', '...
# 28  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 29  {'id': 41898282, 'login': 'github-actions[bot]...
#
#                                                  repo  \
# 0   {'id': 469427410, 'name': 'Jambo2018/react-pol...
# 1   {'id': 483427274, 'name': 'Gransotto2002/QR-Co...
# 2   {'id': 452227954, 'name': 'krithika117/beingkr...
# 3   {'id': 58876201, 'name': 'easylist/easylist', ...
# 4   {'id': 485783953, 'name': 'Smrutthi/M2_Project...
# 5   {'id': 470196260, 'name': 'famturiop/MeetingDa...
# 6   {'id': 219296564, 'name': 'msaltnet/smtm', 'ur...
# 7   {'id': 484046472, 'name': 'tvardero/taChat.App...
# 8   {'id': 484944745, 'name': 'ICTBg/READ-ME', 'ur...
# 9   {'id': 480336626, 'name': 'shsto/crypt', 'url'...
# 10  {'id': 379396407, 'name': 'test-organization-k...
# 11  {'id': 485485397, 'name': '9dcw/associationmar...
# 12  {'id': 240284175, 'name': 'nationalarchives/td...
# 13  {'id': 426008314, 'name': 'mpcamargo1/mpcamarg...
# 14  {'id': 430749584, 'name': 'OneKeyHQ/app-monore...
# 15  {'id': 485720625, 'name': 'dvr16/basic-js', 'u...
# 16  {'id': 109673934, 'name': 'deltachat/deltachat...
# 17  {'id': 416745298, 'name': 'fanteos/SFCM', 'url...
# 18  {'id': 404589015, 'name': 'waittttting/starroc...
# 19  {'id': 482776675, 'name': 'KazantsevaJane/Plag...
# 20  {'id': 90769468, 'name': 'fsultani/my-match', ...
# 21  {'id': 339886674, 'name': 'CarlosLaurine/Carlo...
# 22  {'id': 475788496, 'name': 'AndreiToader1/conna...
# 23  {'id': 247480564, 'name': 'milesholt/autotrade...
# 24  {'id': 479319524, 'name': 'ChristopherNoelGold...
# 25  {'id': 429551228, 'name': 'bullet-dev-team/pyt...
# 26  {'id': 485788648, 'name': 'FateJacobson/Connec...
# 27  {'id': 483328876, 'name': 'patilsayali9822/cor...
# 28  {'id': 135867643, 'name': 'poad/aws-example', ...
# 29  {'id': 437985702, 'name': 'franciscodantas/fra...
#
#                                               payload  public  \
# 0   {'push_id': 9723000668, 'size': 1, 'distinct_s...    True
# 1   {'push_id': 9723000111, 'size': 1, 'distinct_s...    True
# 2   {'push_id': 9723000262, 'size': 1, 'distinct_s...    True
# 3   {'push_id': 9723000647, 'size': 1, 'distinct_s...    True
# 4   {'push_id': 9723000298, 'size': 1, 'distinct_s...    True
# 5   {'push_id': 9723000476, 'size': 1, 'distinct_s...    True
# 6                               {'action': 'started'}    True
# 7   {'action': 'opened', 'number': 8, 'pull_reques...    True
# 8   {'push_id': 9723000474, 'size': 1, 'distinct_s...    True
# 9   {'push_id': 9723000820, 'size': 1, 'distinct_s...    True
# 10  {'action': 'closed', 'issue': {'url': 'https:/...    True
# 11  {'push_id': 9723000808, 'size': 1, 'distinct_s...    True
# 12  {'ref': 'dependabot/npm_and_yarn/ts/graphql-16...    True
# 13  {'push_id': 9723000426, 'size': 1, 'distinct_s...    True
# 14  {'action': 'closed', 'number': 600, 'pull_requ...    True
# 15  {'push_id': 9723000435, 'size': 1, 'distinct_s...    True
# 16  {'action': 'opened', 'number': 1554, 'pull_req...    True
# 17  {'push_id': 9723000941, 'size': 1, 'distinct_s...    True
# 18  {'push_id': 9723000792, 'size': 1, 'distinct_s...    True
# 19  {'push_id': 9723000448, 'size': 1, 'distinct_s...    True
# 20  {'push_id': 9723000617, 'size': 1, 'distinct_s...    True
# 21  {'push_id': 9723000613, 'size': 1, 'distinct_s...    True
# 22  {'push_id': 9723000779, 'size': 55, 'distinct_...    True
# 23  {'push_id': 9723000607, 'size': 1, 'distinct_s...    True
# 24  {'action': 'created', 'issue': {'url': 'https:...    True
# 25  {'ref': 'cicd-e2e-svgmgp', 'ref_type': 'branch...    True
# 26  {'ref': 'main', 'ref_type': 'branch', 'master_...    True
# 27  {'push_id': 9723000398, 'size': 1, 'distinct_s...    True
# 28  {'push_id': 9723000546, 'size': 3, 'distinct_s...    True
# 29  {'push_id': 9723000769, 'size': 1, 'distinct_s...    True
#
#               created_at                                                org
# 0   2022-04-26T13:03:15Z                                                NaN
# 1   2022-04-26T13:03:12Z                                                NaN
# 2   2022-04-26T13:03:13Z                                                NaN
# 3   2022-04-26T13:03:15Z  {'id': 15652042, 'login': 'easylist', 'gravata...
# 4   2022-04-26T13:03:13Z                                                NaN
# 5   2022-04-26T13:03:14Z                                                NaN
# 6   2022-04-26T13:03:15Z                                                NaN
# 7   2022-04-26T13:03:15Z                                                NaN
# 8   2022-04-26T13:03:14Z                                                NaN
# 9   2022-04-26T13:03:16Z                                                NaN
# 10  2022-04-26T13:03:14Z  {'id': 47997193, 'login': 'test-organization-k...
# 11  2022-04-26T13:03:16Z                                                NaN
# 12  2022-04-26T13:03:17Z  {'id': 10154228, 'login': 'nationalarchives', ...
# 13  2022-04-26T13:03:14Z                                                NaN
# 14  2022-04-26T13:03:16Z  {'id': 61685601, 'login': 'OneKeyHQ', 'gravata...
# 15  2022-04-26T13:03:14Z                                                NaN
# 16  2022-04-26T13:03:17Z  {'id': 29453316, 'login': 'deltachat', 'gravat...
# 17  2022-04-26T13:03:17Z                                                NaN
# 18  2022-04-26T13:03:16Z                                                NaN
# 19  2022-04-26T13:03:14Z                                                NaN
# 20  2022-04-26T13:03:15Z                                                NaN
# 21  2022-04-26T13:03:15Z                                                NaN
# 22  2022-04-26T13:03:16Z                                                NaN
# 23  2022-04-26T13:03:15Z                                                NaN
# 24  2022-04-26T13:03:15Z                                                NaN
# 25  2022-04-26T13:03:14Z                                                NaN
# 26  2022-04-26T13:03:14Z                                                NaN
# 27  2022-04-26T13:03:14Z                                                NaN
# 28  2022-04-26T13:03:15Z                                                NaN
# 29  2022-04-26T13:03:16Z                                                NaN

# %%
# to "unpack" all the columns, we can use pd.json_normalize()
pd.json_normalize(response.json())
# Out:
#              id               type  public            created_at   actor.id  \
# 0   21475092000          PushEvent    True  2022-04-26T13:03:15Z   38650337
# 1   21475090914          PushEvent    True  2022-04-26T13:03:12Z  101595139
# 2   21475091289          PushEvent    True  2022-04-26T13:03:13Z   76687631
# 3   21475092014          PushEvent    True  2022-04-26T13:03:15Z    8057368
# 4   21475091288          PushEvent    True  2022-04-26T13:03:13Z   89585989
# 5   21475091635          PushEvent    True  2022-04-26T13:03:14Z    8084401
# 6   21475091981         WatchEvent    True  2022-04-26T13:03:15Z   18066733
# 7   21475091965   PullRequestEvent    True  2022-04-26T13:03:15Z   45442278
# 8   21475091652          PushEvent    True  2022-04-26T13:03:14Z  104293240
# 9   21475092332          PushEvent    True  2022-04-26T13:03:16Z  102516149
# 10  21475091638        IssuesEvent    True  2022-04-26T13:03:14Z   86326137
# 11  21475092287          PushEvent    True  2022-04-26T13:03:16Z   15671329
# 12  21475092660        CreateEvent    True  2022-04-26T13:03:17Z   49699333
# 13  21475091574          PushEvent    True  2022-04-26T13:03:14Z   41898282
# 14  21475092312   PullRequestEvent    True  2022-04-26T13:03:16Z   18140164
# 15  21475091596          PushEvent    True  2022-04-26T13:03:14Z   20303122
# 16  21475092654   PullRequestEvent    True  2022-04-26T13:03:17Z    2614900
# 17  21475092619          PushEvent    True  2022-04-26T13:03:17Z   10129688
# 18  21475092309          PushEvent    True  2022-04-26T13:03:16Z   12523742
# 19  21475091603          PushEvent    True  2022-04-26T13:03:14Z  103194481
# 20  21475091938          PushEvent    True  2022-04-26T13:03:15Z    9757926
# 21  21475091948          PushEvent    True  2022-04-26T13:03:15Z   41898282
# 22  21475092271          PushEvent    True  2022-04-26T13:03:16Z    9108538
# 23  21475091940          PushEvent    True  2022-04-26T13:03:15Z    2687598
# 24  21475091915  IssueCommentEvent    True  2022-04-26T13:03:15Z   40209326
# 25  21475091555        DeleteEvent    True  2022-04-26T13:03:14Z   71354125
# 26  21475091556        CreateEvent    True  2022-04-26T13:03:14Z   82694104
# 27  21475091507          PushEvent    True  2022-04-26T13:03:14Z   92665023
# 28  21475091875          PushEvent    True  2022-04-26T13:03:15Z   49699333
# 29  21475092222          PushEvent    True  2022-04-26T13:03:16Z   41898282
#
#                       actor.login       actor.display_login actor.gravatar_id  \
# 0                       Jambo2018                 Jambo2018
# 1                   Gransotto2002             Gransotto2002
# 2                     krithika117               krithika117
# 3                          monzta                    monzta
# 4                        Smrutthi                  Smrutthi
# 5                       famturiop                 famturiop
# 6                       chingdae1                 chingdae1
# 7                        tvardero                  tvardero
# 8                           ICTBg                     ICTBg
# 9                           shsto                     shsto
# 10                   bot-monkey-7              bot-monkey-7
# 11                           9dcw                      9dcw
# 12                dependabot[bot]                dependabot
# 13            github-actions[bot]            github-actions
# 14                        loaddss                   loaddss
# 15                          dvr16                     dvr16
# 16                        cyBerta                   cyBerta
# 17                        fanteos                   fanteos
# 18                    waittttting               waittttting
# 19                 KazantsevaJane            KazantsevaJane
# 20                       fsultani                  fsultani
# 21            github-actions[bot]            github-actions
# 22                          Annno                     Annno
# 23                      milesholt                 milesholt
# 24                   netlify[bot]                   netlify
# 25  aws-connector-for-github[bot]  aws-connector-for-github
# 26                   FateJacobson              FateJacobson
# 27                patilsayali9822           patilsayali9822
# 28                dependabot[bot]                dependabot
# 29            github-actions[bot]            github-actions
#
#                                             actor.url  \
# 0              https://api.github.com/users/Jambo2018
# 1          https://api.github.com/users/Gransotto2002
# 2            https://api.github.com/users/krithika117
# 3                 https://api.github.com/users/monzta
# 4               https://api.github.com/users/Smrutthi
# 5              https://api.github.com/users/famturiop
# 6              https://api.github.com/users/chingdae1
# 7               https://api.github.com/users/tvardero
# 8                  https://api.github.com/users/ICTBg
# 9                  https://api.github.com/users/shsto
# 10          https://api.github.com/users/bot-monkey-7
# 11                  https://api.github.com/users/9dcw
# 12       https://api.github.com/users/dependabot[bot]
# 13   https://api.github.com/users/github-actions[bot]
# 14               https://api.github.com/users/loaddss
# 15                 https://api.github.com/users/dvr16
# 16               https://api.github.com/users/cyBerta
# 17               https://api.github.com/users/fanteos
# 18           https://api.github.com/users/waittttting
# 19        https://api.github.com/users/KazantsevaJane
# 20              https://api.github.com/users/fsultani
# 21   https://api.github.com/users/github-actions[bot]
# 22                 https://api.github.com/users/Annno
# 23             https://api.github.com/users/milesholt
# 24          https://api.github.com/users/netlify[bot]
# 25  https://api.github.com/users/aws-connector-for...
# 26          https://api.github.com/users/FateJacobson
# 27       https://api.github.com/users/patilsayali9822
# 28       https://api.github.com/users/dependabot[bot]
# 29   https://api.github.com/users/github-actions[bot]
#
#                                      actor.avatar_url  ...  \
# 0   https://avatars.githubusercontent.com/u/38650337?  ...
# 1   https://avatars.githubusercontent.com/u/101595...  ...
# 2   https://avatars.githubusercontent.com/u/76687631?  ...
# 3    https://avatars.githubusercontent.com/u/8057368?  ...
# 4   https://avatars.githubusercontent.com/u/89585989?  ...
# 5    https://avatars.githubusercontent.com/u/8084401?  ...
# 6   https://avatars.githubusercontent.com/u/18066733?  ...
# 7   https://avatars.githubusercontent.com/u/45442278?  ...
# 8   https://avatars.githubusercontent.com/u/104293...  ...
# 9   https://avatars.githubusercontent.com/u/102516...  ...
# 10  https://avatars.githubusercontent.com/u/86326137?  ...
# 11  https://avatars.githubusercontent.com/u/15671329?  ...
# 12  https://avatars.githubusercontent.com/u/49699333?  ...
# 13  https://avatars.githubusercontent.com/u/41898282?  ...
# 14  https://avatars.githubusercontent.com/u/18140164?  ...
# 15  https://avatars.githubusercontent.com/u/20303122?  ...
# 16   https://avatars.githubusercontent.com/u/2614900?  ...
# 17  https://avatars.githubusercontent.com/u/10129688?  ...
# 18  https://avatars.githubusercontent.com/u/12523742?  ...
# 19  https://avatars.githubusercontent.com/u/103194...  ...
# 20   https://avatars.githubusercontent.com/u/9757926?  ...
# 21  https://avatars.githubusercontent.com/u/41898282?  ...
# 22   https://avatars.githubusercontent.com/u/9108538?  ...
# 23   https://avatars.githubusercontent.com/u/2687598?  ...
# 24  https://avatars.githubusercontent.com/u/40209326?  ...
# 25  https://avatars.githubusercontent.com/u/71354125?  ...
# 26  https://avatars.githubusercontent.com/u/82694104?  ...
# 27  https://avatars.githubusercontent.com/u/92665023?  ...
# 28  https://avatars.githubusercontent.com/u/49699333?  ...
# 29  https://avatars.githubusercontent.com/u/41898282?  ...
#
#     payload.comment.reactions.total_count payload.comment.reactions.+1  \
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
# 2                                     NaN                          NaN
# 3                                     NaN                          NaN
# 4                                     NaN                          NaN
# 5                                     NaN                          NaN
# 6                                     NaN                          NaN
# 7                                     NaN                          NaN
# 8                                     NaN                          NaN
# 9                                     NaN                          NaN
# 10                                    NaN                          NaN
# 11                                    NaN                          NaN
# 12                                    NaN                          NaN
# 13                                    NaN                          NaN
# 14                                    NaN                          NaN
# 15                                    NaN                          NaN
# 16                                    NaN                          NaN
# 17                                    NaN                          NaN
# 18                                    NaN                          NaN
# 19                                    NaN                          NaN
# 20                                    NaN                          NaN
# 21                                    NaN                          NaN
# 22                                    NaN                          NaN
# 23                                    NaN                          NaN
# 24                                    0.0                          0.0
# 25                                    NaN                          NaN
# 26                                    NaN                          NaN
# 27                                    NaN                          NaN
# 28                                    NaN                          NaN
# 29                                    NaN                          NaN
#
#    payload.comment.reactions.-1  payload.comment.reactions.laugh  \
# 0                           NaN                              NaN
# 1                           NaN                              NaN
# 2                           NaN                              NaN
# 3                           NaN                              NaN
# 4                           NaN                              NaN
# 5                           NaN                              NaN
# 6                           NaN                              NaN
# 7                           NaN                              NaN
# 8                           NaN                              NaN
# 9                           NaN                              NaN
# 10                          NaN                              NaN
# 11                          NaN                              NaN
# 12                          NaN                              NaN
# 13                          NaN                              NaN
# 14                          NaN                              NaN
# 15                          NaN                              NaN
# 16                          NaN                              NaN
# 17                          NaN                              NaN
# 18                          NaN                              NaN
# 19                          NaN                              NaN
# 20                          NaN                              NaN
# 21                          NaN                              NaN
# 22                          NaN                              NaN
# 23                          NaN                              NaN
# 24                          0.0                              0.0
# 25                          NaN                              NaN
# 26                          NaN                              NaN
# 27                          NaN                              NaN
# 28                          NaN                              NaN
# 29                          NaN                              NaN
#
#     payload.comment.reactions.hooray  payload.comment.reactions.confused  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
# 5                                NaN                                 NaN
# 6                                NaN                                 NaN
# 7                                NaN                                 NaN
# 8                                NaN                                 NaN
# 9                                NaN                                 NaN
# 10                               NaN                                 NaN
# 11                               NaN                                 NaN
# 12                               NaN                                 NaN
# 13                               NaN                                 NaN
# 14                               NaN                                 NaN
# 15                               NaN                                 NaN
# 16                               NaN                                 NaN
# 17                               NaN                                 NaN
# 18                               NaN                                 NaN
# 19                               NaN                                 NaN
# 20                               NaN                                 NaN
# 21                               NaN                                 NaN
# 22                               NaN                                 NaN
# 23                               NaN                                 NaN
# 24                               0.0                                 0.0
# 25                               NaN                                 NaN
# 26                               NaN                                 NaN
# 27                               NaN                                 NaN
# 28                               NaN                                 NaN
# 29                               NaN                                 NaN
#
#    payload.comment.reactions.heart payload.comment.reactions.rocket  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
# 5                              NaN                              NaN
# 6                              NaN                              NaN
# 7                              NaN                              NaN
# 8                              NaN                              NaN
# 9                              NaN                              NaN
# 10                             NaN                              NaN
# 11                             NaN                              NaN
# 12                             NaN                              NaN
# 13                             NaN                              NaN
# 14                             NaN                              NaN
# 15                             NaN                              NaN
# 16                             NaN                              NaN
# 17                             NaN                              NaN
# 18                             NaN                              NaN
# 19                             NaN                              NaN
# 20                             NaN                              NaN
# 21                             NaN                              NaN
# 22                             NaN                              NaN
# 23                             NaN                              NaN
# 24                             0.0                              0.0
# 25                             NaN                              NaN
# 26                             NaN                              NaN
# 27                             NaN                              NaN
# 28                             NaN                              NaN
# 29                             NaN                              NaN
#
#    payload.comment.reactions.eyes payload.comment.performed_via_github_app
# 0                             NaN                                      NaN
# 1                             NaN                                      NaN
# 2                             NaN                                      NaN
# 3                             NaN                                      NaN
# 4                             NaN                                      NaN
# 5                             NaN                                      NaN
# 6                             NaN                                      NaN
# 7                             NaN                                      NaN
# 8                             NaN                                      NaN
# 9                             NaN                                      NaN
# 10                            NaN                                      NaN
# 11                            NaN                                      NaN
# 12                            NaN                                      NaN
# 13                            NaN                                      NaN
# 14                            NaN                                      NaN
# 15                            NaN                                      NaN
# 16                            NaN                                      NaN
# 17                            NaN                                      NaN
# 18                            NaN                                      NaN
# 19                            NaN                                      NaN
# 20                            NaN                                      NaN
# 21                            NaN                                      NaN
# 22                            NaN                                      NaN
# 23                            NaN                                      NaN
# 24                            0.0                                      NaN
# 25                            NaN                                      NaN
# 26                            NaN                                      NaN
# 27                            NaN                                      NaN
# 28                            NaN                                      NaN
# 29                            NaN                                      NaN
#
# [30 rows x 438 columns]

# %% [markdown]
# ### Intenational Space Station
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get("http://api.open-notify.org/iss-now.json")
# Print the status code of the response.
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'timestamp': 1650978505,
#  'message': 'success',
#  'iss_position': {'longitude': '-111.7456', 'latitude': '49.4063'}}

# %% [markdown]
# {'iss_position': {'latitude': '10.7064', 'longitude': '-27.9890'},
#  'message': 'success',
#  'timestamp': 1623745101}

# %%
# last time it was over ironhack
  ## 52.53370520371973, 13.453475292072312
coordinates = {"lat": 52.53370520371973, "lon": 13.453475292072312}
response = requests.get("http://api.open-notify.org/iss-pass.json", params=coordinates)

# %%
response.status_code
# Out:
# 200

# %%
response.url
# Out:
# 'http://api.open-notify.org/iss-pass.json?lat=52.53370520371973&lon=13.453475292072312'

# %%
response = requests.get('http://api.open-notify.org/iss-pass.json?lat=52.53370520371973&lon=13.453475292072312')

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1650978537,
#   'latitude': 52.53370520371973,
#   'longitude': 13.453475292072312,
#   'passes': 5},
#  'response': [{'duration': 210, 'risetime': 1651022628},
#   {'duration': 580, 'risetime': 1651028180},
#   {'duration': 645, 'risetime': 1651033924},
#   {'duration': 652, 'risetime': 1651039720},
#   {'duration': 639, 'risetime': 1651045522}]}

# %%
from datetime import datetime
datetime.fromtimestamp(1645005884)
# Out:
# datetime.datetime(2022, 2, 16, 11, 4, 44)

# %%
pd.to_datetime(1637772367, unit="s")
# Out:
# Timestamp('2021-11-24 16:46:07')
